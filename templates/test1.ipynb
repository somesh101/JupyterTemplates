# %% [markdown]
# # Top Heading

# %%
print("hello World")
# Out:
# hello World

# %%
x= 1
y=2
x+y
# Out:
# 3

# %%
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(z)
#
# NameError: name 'z' is not defined

# %%
print({'x':1,'y':2})
# Out:
# {'x': 1, 'y': 2}
