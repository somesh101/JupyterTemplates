# %%
import pandas as pd

# %%
# prompt: create a sample datraframe and print it
data = {'Name': ['Alice', 'Bob', 'Claire'], 'Age': [25, 30, 27]}

df = pd.DataFrame(data)

print(df.to_string())
# Out:
#      Name  Age
# 0   Alice   25
# 1     Bob   30
# 2  Claire   27

# %%
# prompt: from the df create a bar graphon Name field

df.plot.bar(x='Name', y='Age')
# Out:
# <Axes: xlabel='Name'>

# %%
# markdown

# %% [markdown]
# # Heading

# %%
df.sum()
# Out:
# Name    AliceBobClaire
# Age                 82
# dtype: object

# %%
df.Age.sum()
# Out:
# 82

# %%
df.er
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e28742df6e1b> in <cell line: 1>()
# ----> 1 df.er
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'er'

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
"hello Collab"
# Out:
# 'hello Collab'
